# %%
#!pip install meetup.api

# %%
import meetup.api
import json 
import requests 
import time 
import codecs
import sys
import io
import re
import pandas as pd
import sqlalchemy as sa
import string

# %%
def getCreds(filename,subset,defaults={}):
    '''
    This function helps us connect to a database on hadoop2.  The
    userid password information is stored in a local file encoded
    in json format.  
    Parameters:
    filename is where json encoded userid/password information stored
    subset: dictionary key in json file
    defaults: alternative way to connect to database
    Returns: subdictionary based on subset parameter.
    '''
    try:
        with open(filename,'r') as file:
            D = json.load(file)
            file.close()
            if D[subset]:
                return D[subset]
            else:
                return defaults
    except:
        return defaults

def db_setup(userid,password):
    '''
    This function connects us to a database using our login credentials. 
    Paramters:
    userid - string with our userid
    password - string with our password
    database - string with database name
    Returns:
    SQL engine and SQL connection objects
    '''
    template = 'mysql+mysqlconnector://{}:{}@hadoop2.mathsci.denison.edu/'
    cstring = template.format(userid,password)
    engine = sa.create_engine(cstring)
    connection = engine.connect()
    
    return engine, connection

# %%
def scrapeData(protocol, host, resource):
    '''
    This function takes elements of a URL and returns the raw text from
    the webpage.
    Parameters: protocol, host, resource
    Returns: response text
    '''
    template = "{}://{}{}"
    url = template.format(protocol, host, resource)
    resp = requests.get(url)
    if resp.status_code == 200:
        return resp.text
    print("Error")

def extractSectionBetween(txt, start, end):
    '''
    Slices text by substring boundaries rather than index boundaries.
    Parameters: text to slice, start string, end string
    Returns: trimmed string
    '''
    startInd = txt.find(start)
    endInd = txt.find(end)
    return txt[startInd:endInd]

def recreateTable(txt):
    '''
    Takes text containing a table in raw HTML format and
    places desired data in a pandas data frame.
    Parameters: html text
    Returns: pandas data frame
    '''
    pat = re.compile(r"<td><a .*?>(?P<county>.*?)<\/a>\n<\/td>\n<td .*?>(?P<pop>.*?)\n<\/td>")
    countyid = []
    i = 1
    county = []
    state = []
    pop = []
    for m in pat.finditer(txt):
        county.append(m["county"].split(",")[0].strip())
        state.append(m["county"].split(",")[1].strip())
        pop.append(int(m["pop"].replace(",", "")))
        countyid.append(i)
        i += 1
    return pd.DataFrame({"CountyID":countyid, "County":county, "State":state, "Population":pop})

# %%
def makeDataFrame(name, uid, state, city, lon, lat):
    uniqueStates = set(state)
    uniqueStates = list(uniqueStates)
    uniqueStates.sort()
    statesMap = {}
    for i in range(len(uniqueStates)):
        statesMap[uniqueStates[i]]=i+1
    for i in range(len(name)):
        for j in name[i]: 
            if (j not in string.printable) or (j in string.punctuation):
                name[i] = 'badName'
                break
        state[i]=statesMap[state[i]]
    df = pd.DataFrame({"name":name, "uid":uid, "state":state, "city":city, "lon":lon, "lat":lat})
    return df, statesMap

def superFetch(groupname, key):
    print("Start fetching...")
    client = meetup.api.Client(key)
    print('request status:',end=' ')
    group = client.GetGroup({'urlname':groupname})
    gid = group.id
    total = group.members
    want = 'id,name,state,city,lon,lat'
    limit = 200
    request = total//limit+1
    offsetValue = 0
    name = []
    uid = []
    state = []
    city = []
    lon = []
    lat = []
    for i in range(request):
        print('progress: ',offsetValue+1,'/',request, sep='', end=' ')
        print('request status:',end=' ')
        try:
            members = client.GetMembers(group_id=gid, only=want,page=limit,offset=offsetValue)
            offsetValue+=1
            rList= members.results
            for j in rList:
                if len(j.keys())==4:
                    name.append(j['name'])
                    uid.append(j['id'])
                    state.append(j['state'])
                    city.append(j['city'])
                else:
                    uid.append(j['id'])
                    try:
                        name.append(j['name'])
                    except KeyError:
                        name.append('badName')
                    try:
                        state.append(j['state'])
                    except KeyError:
                        state.append('Atlantis')
                    try:
                        city.append(j['city'])
                    except:
                        city.append('Atlantis')
                    try:
                        lon.append(j['lon'])
                        lat.append(j['lat'])
                    except:
                        lon.append('null')
                        lat.append('null')
        except json.decoder.JSONDecodeError:
            print("JSONDecodeError")
    print("fetching complete")
    df, stateMap = makeDataFrame(name, uid, state, city, lon, lat)
    return df, stateMap

# %%
key = '1a60703a102a6252424875415c1b21'
userTable, stateMap = superFetch('Data-Science-DC', key)

txt = scrapeData("https", "en.wikipedia.org", "/wiki/Washington_metropolitan_area")
txt = extractSectionBetween(txt, "92.3 years", "The Washington, D.C. area has the largest science")
popTable = recreateTable(txt)
popTable["State"] = popTable["State"].replace("D.C.", stateMap['DC'])
popTable["State"] = popTable["State"].replace("Maryland", stateMap['MD'])
popTable["State"] = popTable["State"].replace("Virginia", stateMap['VA'])
print(popTable)
# Out:
# Start fetching...
# request status: 29/30 (10 seconds remaining)
# progress: 1/58 request status: 28/30 (10 seconds remaining)
# progress: 2/58 request status: 27/30 (5 seconds remaining)
# progress: 3/58 request status: 26/30 (3 seconds remaining)
# progress: 4/58 request status: 29/30 (10 seconds remaining)
# progress: 5/58 request status: 28/30 (8 seconds remaining)
# progress: 6/58 request status: 27/30 (5 seconds remaining)
# progress: 7/58 request status: 26/30 (2 seconds remaining)
# progress: 8/58 request status: 25/30 (0 seconds remaining)
# progress: 9/58 request status: 29/30 (10 seconds remaining)
# progress: 10/58 request status: 28/30 (8 seconds remaining)
# progress: 11/58 request status: 27/30 (6 seconds remaining)
# progress: 12/58 request status: 26/30 (4 seconds remaining)
# progress: 13/58 request status: 25/30 (2 seconds remaining)
# JSONDecodeError
# progress: 13/58 request status: 29/30 (10 seconds remaining)
# progress: 14/58 request status: 28/30 (8 seconds remaining)
# JSONDecodeError
# progress: 14/58 request status: 27/30 (6 seconds remaining)
# progress: 15/58 request status: 26/30 (3 seconds remaining)
# progress: 16/58 request status: 25/30 (1 seconds remaining)
# progress: 17/58 request status: 29/30 (10 seconds remaining)
# JSONDecodeError
# progress: 17/58 request status: 28/30 (7 seconds remaining)
# progress: 18/58 request status: 27/30 (5 seconds remaining)
# progress: 19/58 request status: 26/30 (3 seconds remaining)
# progress: 20/58 request status: 25/30 (1 seconds remaining)
# progress: 21/58 request status: 29/30 (10 seconds remaining)
# progress: 22/58 request status: 28/30 (8 seconds remaining)
# progress: 23/58 request status: 27/30 (6 seconds remaining)
# JSONDecodeError
# progress: 23/58 request status: 26/30 (4 seconds remaining)
# progress: 24/58 request status: 25/30 (1 seconds remaining)
# progress: 25/58 request status: 29/30 (10 seconds remaining)
# progress: 26/58 request status: 28/30 (8 seconds remaining)
# progress: 27/58 request status: 27/30 (6 seconds remaining)
# JSONDecodeError
# progress: 27/58 request status: 26/30 (4 seconds remaining)
# progress: 28/58 request status: 25/30 (2 seconds remaining)
# progress: 29/58 request status: 24/30 (0 seconds remaining)
# progress: 30/58 request status: 29/30 (10 seconds remaining)
# progress: 31/58 request status: 28/30 (8 seconds remaining)
# JSONDecodeError
# progress: 31/58 request status: 27/30 (5 seconds remaining)
# progress: 32/58 request status: 26/30 (3 seconds remaining)
# progress: 33/58 request status: 25/30 (1 seconds remaining)
# progress: 34/58 request status: 29/30 (10 seconds remaining)
# progress: 35/58 request status: 28/30 (8 seconds remaining)
# progress: 36/58 request status: 27/30 (5 seconds remaining)
# progress: 37/58 request status: 26/30 (3 seconds remaining)
# progress: 38/58 request status: 25/30 (1 seconds remaining)
# progress: 39/58 request status: 29/30 (10 seconds remaining)
# progress: 40/58 request status: 28/30 (8 seconds remaining)
# progress: 41/58 request status: 27/30 (6 seconds remaining)
# progress: 42/58 request status: 26/30 (4 seconds remaining)
# progress: 43/58 request status: 25/30 (2 seconds remaining)
# progress: 44/58 request status: 29/30 (10 seconds remaining)
# progress: 45/58 request status: 28/30 (8 seconds remaining)
# progress: 46/58 request status: 27/30 (6 seconds remaining)
# progress: 47/58 request status: 26/30 (3 seconds remaining)
# progress: 48/58 request status: 25/30 (1 seconds remaining)
# progress: 49/58 request status: 29/30 (10 seconds remaining)
# progress: 50/58 request status: 28/30 (7 seconds remaining)
# progress: 51/58 request status: 27/30 (5 seconds remaining)
# progress: 52/58 request status: 26/30 (3 seconds remaining)
# fetching complete
#     CountyID                  County  State  Population
# 0          1              Washington     14      681170
# 1          2          Calvert County     30       91251
# 2          3          Charles County     30      157705
# 3          4        Frederick County     30      247591
# 4          5       Montgomery County     30     1043863
# 5          6  Prince George's County     30      908049
# 6          7              Alexandria     58      155810
# 7          8        Arlington County     58      230050
# 8          9           Clarke County     58       14374
# 9         10         Culpeper County     58       50083
# 10        11          Fairfax County     58     1138652
# 11        12            Fairfax City     58       24164
# 12        13            Falls Church     58       14014
# 13        14         Fauquier County     58       69069
# 14        15          Fredericksburg     58       28297
# 15        16          Loudoun County     58      385945
# 16        17                Manassas     58       41483
# 17        18           Manassas Park     58       15915
# 18        19   Prince William County     58      455210
# 19        20     Rappahannock County     58        7388
# 20        21     Spotsylvania County     58      132010
# 21        22         Stafford County     58      144361
# 22        23           Warren County     58       39155

# %%
creds = getCreds('creds.json','mysql',defaults = {'user':'studen_j1', 'password':'studen_j1'})
try:
    connection.close()
    del engine
except:
    pass
engine, connection = db_setup(creds['user'],creds['password'])

# %%
makeDB = "CREATE DATABASE wang_j2;"

makeCountyPopulations = "CREATE TABLE CountyPopulations(\
CountyID INT NOT NULL,\
CountyName VARCHAR(30),\
StateID INT,\
Population INT,\
PRIMARY KEY(CountyID)\
);"

makeStates = "CREATE TABLE States(\
StateID INT NOT NULL,\
State VARCHAR(30),\
PRIMARY KEY(StateID)\
);"

makeUsers = "CREATE TABLE Users(\
MemberID INT NOT NULL,\
Nickname VARCHAR(30),\
StateID INT,\
UserCity VARCHAR(30),\
UserLongitude DECIMAL(5, 2),\
UserLatitude DECIMAL(5, 2),\
PRIMARY KEY(MemberID)\
);"

# %%
# connection.execute("commit;")
# connection.execute(makeDB)
# connection.execute("USE wang_j2;")
# connection.execute(makeCountyPopulations)
# connection.execute(makeStates)
# connection.execute(makeUsers)

# %%
def insertCounty(df):
    valuesTemplate1 = '({},{},{},{})'
    countyRowTemplate = "INSERT INTO CountyPopulations(CountyID, CountyName, StateID, Population)VALUES{};"
    valueRows = ""
    for i in range(len(df)):
        countyRow = valuesTemplate1.format(df.iloc[i, 0], "'"+df.iloc[i, 1].replace("'", "")+"'", df.iloc[i, 2], df.iloc[i, 3])
        valueRows += "," + countyRow
    insertString = countyRowTemplate.format(valueRows[1:])
    print(insertString)
    #connection.execute(insertString)
    
def insertUser(df):
    valuesTemplate2 = '({},{},{},{},{},{})'
    usersRowTemplate = "INSERT INTO Users(MemberID, Nickname, StateID, UserCity, UserLongitude, UserLatitude)VALUES{};"
    valueRows = ""
    for i in range(len(df)):
        userRow = valuesTemplate2.format(df.iloc[i,1], "'"+df.iloc[i, 0]+"'", df.iloc[i, 2], "'"+df.iloc[i, 3]+"'", df.iloc[i, 4], df.iloc[i, 5])
        valueRows += "," + userRow
    insertString = usersRowTemplate.format(valueRows[1:])
    print(insertString)
    #connection.execute(insertString)

insertCounty(popTable)
insertUser(userTable)

print(userTable)

stateRowTemplate = "INSERT INTO States\
(StateID, State)\
VALUES({},{});"

usersRowTemplate = "INSERT INTO Users\
(MemberID, Nickname, StateID, UserCity, UserLongitude, UserLatitude)\
VALUES({},{},{},{},{},{});"

# for i in range(len(popTable)):
#     countyRow = countyRowTemplate.format(popTable.iloc[i, 0], "'"+popTable.iloc[i, 1].replace("'", "")+"'", popTable.iloc[i, 2], popTable.iloc[i, 3])
#     connection.execute(countyRow)

# StateList = list(stateMap.keys())
# StateIDList = list(stateMap.values())
# for i in range(len(StateList)):
#     stateRow = stateRowTemplate.format(StateIDList[i], "'"+StateList[i]+"'")
#     connection.execute(stateRow)

# for i in range(len(df)):
#     if i % 300 == 0:
#         print(i)
#     usersRow = usersRowTemplate.format(df.iloc[i,1], "'"+df.iloc[i, 0]+"'", df.iloc[i, 2], "'"+df.iloc[i, 3]+"'", df.iloc[i, 4], df.iloc[i, 5])
#     connection.execute(usersRow)
# Out:
# INSERT INTO CountyPopulations(CountyID, CountyName, StateID, Population)VALUES(1,'Washington',14,681170),(2,'Calvert County',30,91251),(3,'Charles County',30,157705),(4,'Frederick County',30,247591),(5,'Montgomery County',30,1043863),(6,'Prince Georges County',30,908049),(7,'Alexandria',58,155810),(8,'Arlington County',58,230050),(9,'Clarke County',58,14374),(10,'Culpeper County',58,50083),(11,'Fairfax County',58,1138652),(12,'Fairfax City',58,24164),(13,'Falls Church',58,14014),(14,'Fauquier County',58,69069),(15,'Fredericksburg',58,28297),(16,'Loudoun County',58,385945),(17,'Manassas',58,41483),(18,'Manassas Park',58,15915),(19,'Prince William County',58,455210),(20,'Rappahannock County',58,7388),(21,'Spotsylvania County',58,132010),(22,'Stafford County',58,144361),(23,'Warren County',58,39155);
# INSERT INTO Users(MemberID, Nickname, StateID, UserCity, UserLongitude, UserLatitude)VALUES(126079712,'badName',14,'Washington',-77.05,38.9),(2388112,'badName',14,'Washington',-77.02,38.91),(13184811,'badName',11,'San Francisco',-122.44,37.8),(4286018,'badName',30,'Columbia',-76.88,39.21),(41459102,'A',30,'La Plata',-76.97,38.52),(198289359,'A',58,'Reston',-77.34,38.96),(219816903,'A',14,'Washington',-77.02,38.91),(210503877,'A',61,'Bellingham',-122.44,48.76),(243220615,'A B',14,'Washington',-77.02,38.91),(52767982,'A Briggs',14,'Washington',-77.02,38.91),(215523843,'A DL',14,'Washington',-77.0,38.92),(260647258,'A Saiyed',14,'Washington',-77.02,38.91),(227345101,'A Williams',58,'Arlington',-77.09,38.84),(156714622,'badName',14,'Washington',-77.02,38.91),(262490346,'badName',14,'Washington',-77.03,38.91),(209021813,'badName',30,'Potomac',-77.24,39.03),(244623262,'badName',14,'Washington',-77.04,38.92),(204791660,'badName',14,'Washington',-77.08,38.91),(231664777,'badName',58,'Arlington',-77.1,38.89),(190103751,'badName',58,'Fairfax',-77.36,38.86),(183610329,'badName',14,'Washington',-77.02,38.91),(210312434,'Aakash Ahamed',14,'Washington',-77.02,38.91),(237364773,'Aakash Bhatia',46,'Pittsburgh',-79.93,40.45),(185687584,'Aakrit Shrestha',14,'Washington',-77.03,38.91),(210735553,'Aalekh Gupta',58,'Arlington',-77.1,38.89),(112010002,'Aamir Khwaja',58,'Arlington',-77.06,38.86),(53551712,'Aarati',11,'Irvine',-117.83,33.68),(303432,'Aaron',58,'Arlington',-77.06,38.86),(10120491,'Aaron',2,'London',-0.1,51.5),(18038591,'Aaron',30,'Gaithersburg',-77.24,39.11),(144110322,'Aaron',30,'Silver Spring',-77.04,39.0),(75664912,'Aaron',30,'Columbia',-76.82,39.17),(143111762,'Aaron',14,'Washington',-77.02,38.91),(238748121,'Aaron',14,'Washington',-77.02,38.91),(660365,'Aaron',38,'Teaneck',-74.01,40.89),(45403702,'Aaron',30,'Towson',-76.57,39.4),(62914202,'Aaron',58,'Arlington',-77.1,38.86),(13617288,'Aaron',14,'Washington',-77.02,38.95),(205410275,'Aaron B',14,'Washington',-76.97,38.86),(231096417,'Aaron Bias',14,'Washington',-77.09,38.96),(123264622,'Aaron Black',58,'Fairfax',-77.26,38.85),(237241522,'Aaron Broderick',30,'Baltimore',-76.63,39.27),(98896662,'Aaron Burciaga',30,'Baltimore',-76.63,39.27),(231310094,'Aaron Chafetz',14,'Washington',-77.02,38.91),(141726332,'Aaron Chandler',14,'Washington',-77.04,38.9),(11588309,'Aaron Davis',56,'Lehi',-111.85,40.39),(185338604,'Aaron Davis',30,'Chevy Chase',-77.08,38.98),(256776513,'Aaron Del Giudice',14,'Washington',-77.02,38.91),(230161181,'Aaron Drotts',8,'Berlin',13.38,52.52),(93893232,'Aaron Duke',61,'Olympia',-122.97,47.03),(197553450,'Aaron Gawronsky',58,'Arlington',-77.1,38.89),(49594582,'Aaron Gussman',58,'Arlington',-77.1,38.89),(17492111,'Aaron holm',14,'Washington',-77.04,38.9),(139136912,'Aaron Hull',30,'Laurel',-76.88,39.1),(223542912,'Aaron Hung',14,'Washington',-77.06,38.86),(186530239,'Aaron Katch',62,'Milwaukee',-87.92,43.04),(233794560,'Aaron Katz',58,'Arlington',-77.1,38.89),(193796868,'Aaron Lee',14,'Washington',-77.05,38.9),(261979634,'Aaron Lutkowitz',14,'Washington',-77.03,38.91),(8783792,'Aaron M',58,'Alexandria',-77.05,38.8),(183878524,'Aaron Pujanandez',30,'Silver Spring',-77.06,39.08),(206739,'aaron r',14,'Washington',-77.04,38.92),(174018832,'Aaron Rappaport',14,'Washington',-77.02,38.91),(232795520,'Aaron Reilly',41,'New York',-73.98,40.72),(9553301,'Aaron Sander',30,'Silver Spring',-77.04,39.0),(197684904,'badName',58,'Arlington',-77.1,38.89),(238584232,'badName',14,'Washington',-77.02,38.91),(48544182,'Aaron Schein',14,'Washington',-77.02,38.91),(153298922,'Aaron Schroeder',58,'Arlington',-77.1,38.89),(25039192,'Aaron Schumacher',14,'Washington',-77.05,38.9),(116099302,'Aaron Shen',14,'Washington',-77.04,38.9),(224995271,'Aaron Williams',58,'Charlottesville',-78.49,38.06),(148211152,'Aarzu',14,'Washington',-76.99,38.88),(78737012,'Ab Boxley',14,'Washington',-77.04,38.91),(75003172,'abbas',23,'Chicago',-87.64,41.88),(221170242,'Abbas Arab',58,'Reston',-77.35,38.94),(14 ...
#                           name        uid  state           city     lon    lat
# 0                      badName  126079712     14     Washington  -77.05  38.90
# 1                      badName    2388112     14     Washington  -77.02  38.91
# 2                      badName   13184811     11  San Francisco -122.44  37.80
# 3                      badName    4286018     30       Columbia  -76.88  39.21
# 4                            A   41459102     30       La Plata  -76.97  38.52
# 5                            A  198289359     58         Reston  -77.34  38.96
# 6                            A  219816903     14     Washington  -77.02  38.91
# 7                            A  210503877     61     Bellingham -122.44  48.76
# 8                          A B  243220615     14     Washington  -77.02  38.91
# 9                     A Briggs   52767982     14     Washington  -77.02  38.91
# 10                        A DL  215523843     14     Washington  -77.00  38.92
# 11                    A Saiyed  260647258     14     Washington  -77.02  38.91
# 12                  A Williams  227345101     58      Arlington  -77.09  38.84
# 13                     badName  156714622     14     Washington  -77.02  38.91
# 14                     badName  262490346     14     Washington  -77.03  38.91
# 15                     badName  209021813     30        Potomac  -77.24  39.03
# 16                     badName  244623262     14     Washington  -77.04  38.92
# 17                     badName  204791660     14     Washington  -77.08  38.91
# 18                     badName  231664777     58      Arlington  -77.10  38.89
# 19                     badName  190103751     58        Fairfax  -77.36  38.86
# 20                     badName  183610329     14     Washington  -77.02  38.91
# 21               Aakash Ahamed  210312434     14     Washington  -77.02  38.91
# 22               Aakash Bhatia  237364773     46     Pittsburgh  -79.93  40.45
# 23             Aakrit Shrestha  185687584     14     Washington  -77.03  38.91
# 24                Aalekh Gupta  210735553     58      Arlington  -77.10  38.89
# 25                Aamir Khwaja  112010002     58      Arlington  -77.06  38.86
# 26                      Aarati   53551712     11         Irvine -117.83  33.68
# 27                       Aaron     303432     58      Arlington  -77.06  38.86
# 28                       Aaron   10120491      2         London   -0.10  51.50
# 29                       Aaron   18038591     30   Gaithersburg  -77.24  39.11
# ...                        ...        ...    ...            ...     ...    ...
# 10370                  badName   74545092     14     Washington  -77.02  38.91
# 10371                  badName    6343037     58         Reston  -77.35  38.94
# 10372              Thomas Park   34280602     14     Washington  -77.02  38.91
# 10373  Thomas Patrick Callahan  188841816     58    Springfield  -77.24  38.78
# 10374         Thomas Plapinger  155871122     14     Washington  -77.04  38.92
# 10375                  badName  196864016     58        Fairfax  -77.34  38.83
# 10376            Thomas Radman  182181892     14     Washington  -77.02  38.91
# 10377      Thomas Schellenberg  138226532     58   Falls Church  -77.19  38.90
# 10378              Thomas Tang  219315596     14     Washington  -77.02  38.91
# 10379               Thong Tran  121443812     58        Fairfax  -77.34  38.83
# 10380                  thwllms  116801992     58        Herndon  -77.39  38.98
# 10381            Tiago Ventura  222104909     30         Laurel  -76.88  39.10
# 10382                    Tiana   12475834     14     Washington  -77.02  38.91
# 10383              Tianning Xu  247406977     58      Arlington  -77.07  38.89
# 10384              Tianshu Sun   41473432     14     Washington  -77.03  38.91
# 10385             Tianzhen Lin    6975666     58        Fairfax  -77.26  38.85
# 10386                   Tiarra  217454950     14     Washington  -76.99  38.91
# 10387                  Tiarra   183257512     14     Washington  -77.07  38.91
# 10388                     Tich  190006146     14     Washington  -77.04  38.91
# 10389                 Tieu luu   68811722     14     Washington  -77.07  38.91
# 10390                  Tiffany   37133092     14     Washington  -77.02  38.95
# 10391                  Tiffany  182515458     14     Washington  -77.02  38.91
# 10392                  Tiffany  182769908     14     Washington  -76.97  38.86
# 10393                  Tiffany  228108556     30   Gaithersburg  -77.19  39.14
# 10394                  Tiffany  231702843     14     Washington  -77.07  38.91
# 10395                  Tiffany  188212759     30       Bethesda  -77.10  38.98
# 10396           Tiffany Harlan  187757318     30    Hyattsville  -76.97  38.96
# 10397           Tiffany Manuel   86304002     14     Washington  -77.02  38.91
# 10398        Tiffany Schleeter  209492615     14     Washington  -77.02  38.91
# 10399            Tiffany Small  187373362     14     Washington  -77.04  38.92
#
# [10400 rows x 6 columns]

# %%
try:
    connection.close()
    del engine
    print("Connection closed")
except:
    pass
    print("No connection")
# Out:
# Connection closed
